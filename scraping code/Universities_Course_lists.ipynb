# %% [markdown]
# # Waterloo University Course Lists

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests

import matplotlib.pyplot as plt
import numpy as np
## For Preparing Features to Model
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer


try:
    from wordcloud import WordCloud
except:
    # !pip install wordcloud
    from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
url="https://uwaterloo.ca/graduate-studies-academic-calendar/mathematics/data-science-and-artificial-intelligence/master-data-science-and-artificial-intelligence-mdsai-co-operative-program-direct-entry#coursework"
resp = requests.get(url)
soup = BeautifulSoup(resp.content)

# %%
t=[]

for text in soup.find_all(name="div", attrs={"class":"field-content field-item"}):
  for li in text.find_all(name="li"):  
    t.append(li.text)

# %%
t
# Out:
# ['\nStudents must complete at least 9 courses: normally 1 foundation course, 5 core courses, and 3 elective courses.\n',
#  '\nFoundation courses\n\nStudents are expected to take at most 1 of the following 2 foundational courses depending on their undergraduate major:\n\nCS 600 Fundamentals of Computer Science for Data Science (designed for non-CS major background students)\n\n\nSTAT 845 Statistical Concepts for Data Science (designed for non-STAT major background students)\n\n\n',
#  '\nStudents are expected to take at most 1 of the following 2 foundational courses depending on their undergraduate major:\n\nCS 600 Fundamentals of Computer Science for Data Science (designed for non-CS major background students)\n\n\nSTAT 845 Statistical Concepts for Data Science (designed for non-STAT major background students)\n\n',
#  '\nCS 600 Fundamentals of Computer Science for Data Science (designed for non-CS major background students)\n',
#  '\nSTAT 845 Statistical Concepts for Data Science (designed for non-STAT major background students)\n',
#  '\nCore courses\n\nStudents are required to take the following core courses:\n\n\nSTAT 847 Exploratory Data Analysis\n\n\n1 of:\n\nCS 651 Data-Intensive Distributed Computing (designed for CS major background students), or\n\n\nCS 631 Data-Intensive Distributed Analytics (designed for non-CS major background students)\n\n\n\n1 of:\n\nSTAT 841 Statistical Learning - Classification\n\n\nSTAT 842 Data Visualization\n\n\nSTAT 844 Statistical Learning - Function Estimation\n\n\n\n1 of:\n\nCS 638 Principles of Data Management and Use\n\n\nCS 648 Database Systems Implementation\n\n\nCS 680 Introduction to Machine Learning\n\n\nCS 685 Machine Learning: Statistical and Computational Foundations\n\n\n\n1 of:\n\nCO 602 / CS 795 Fundamentals of Optimization\n\n\nCO 673 / CS 794 Optimization for Data Science\n\n\nCO 663 Convex Optimization and Analysis\n\n\n',
#  '\nStudents are required to take the following core courses:\n',
#  '\nSTAT 847 Exploratory Data Analysis\n',
#  '\n1 of:\n\nCS 651 Data-Intensive Distributed Computing (designed for CS major background students), or\n\n\nCS 631 Data-Intensive Distributed Analytics (designed for non-CS major background students)\n\n',
#  '\nCS 651 Data-Intensive Distributed Computing (designed for CS major background students), or\n',
#  '\nCS 631 Data-Intensive Distributed Analytics (designed for non-CS major background students)\n',
#  '\n1 of:\n\nSTAT 841 Statistical Learning - Classification\n\n\nSTAT 842 Data Visualization\n\n\nSTAT 844 Statistical Learning - Function Estimation\n\n',
#  '\nSTAT 841 Statistical Learning - Classification\n',
#  '\nSTAT 842 Data Visualization\n',
#  '\nSTAT 844 Statistical Learning - Function Estimation\n',
#  '\n1 of:\n\nCS 638 Principles of Data Management and Use\n\n\nCS 648 Database Systems Implementation\n\n\nCS 680 Introduction to Machine Learning\n\n\nCS 685 Machine Learning: Statistical and Computational Foundations\n\n',
#  '\nCS 638 Principles of Data Management and Use\n',
#  '\nCS 648 Database Systems Implementation\n',
#  '\nCS 680 Introduction to Machine Learning\n',
#  '\nCS 685 Machine Learning: Statistical and Computational Foundations\n',
#  '\n1 of:\n\nCO 602 / CS 795 Fundamentals of Optimization\n\n\nCO 673 / CS 794 Optimization for Data Science\n\n\nCO 663 Convex Optimization and Analysis\n\n',
#  '\nCO 602 / CS 795 Fundamentals of Optimization\n',
#  '\nCO 673 / CS 794 Optimization for Data Science\n',
#  '\nCO 663 Convex Optimization and Analysis\n',
#  '\nElective Courses\n\nStudents must take enough additional elective courses to fulfill the 9-course requirement. These courses must normally be taken from the following list of selected graduate courses. Courses not on this list are subject to the approval of the Graduate Director.\n\nCO 602 / CS 795 Fundamentals of Optimization\n\n\nCO 673 / CS 794 Optimization for Data Science\n\n\nCO 650 Combinatorial Optimization\n\n\nCO 663 Convex Optimization and Analysis\n\n\nCO 769 Topics in Continuous Optimization(*)\n\n\nCS 638 Principles of Data Management and Use\n\n\nCS 648 Database Systems Implementation\n\n\nCS 654 Distributed Systems\n\n\nCS 680 Introduction to Machine Learning\n\n\nCS 685 Machine Learning: Statistical and Computational Foundations\n\n\nCS 686 Introduction to Artificial Intelligence\n\n\nCS 740 Database Engineering\n\n\nCS 742 Parallel and Distributed Database Systems\n\n\nCS 743 Principles of Database Management and Use\n\n\nCS 786 Probabilistic Inference and Machine Learning\n\n\nCS 798 Advanced Research Topics(*)\n\n\nCS 848 Advanced Topics in Databases(*)\n\n\nCS 856 Advanced Topics in Distributed Computing(*)\n\n\nCS 885 Advanced Topics in Computational Statistics(*)\n\n\nCS 886 Advanced Topics in Artificial Intelligence\n\n\nSTAT 840 Computational Inference\n\n\nSTAT 841 Statistical Learning - Classification\n\n\nSTAT 842 Data Visualization\n\n\nSTAT 844 Statistical Learning - Function Estimation\n\n\nSTAT 946 Topics in Probability and Statistics(*)\n\n\nDS 701/702 Data Science Project 1 & 2\n\n\n\nNote (*): CO 769, CS 798, CS courses at the 800 level, and STAT courses at the 900 level should be on a topic in Data Science or Artificial Intelligence; they are subject to the approval of the Graduate Officer.\n\n',
#  '\nStudents must take enough additional elective courses to fulfill the 9-course requirement. These courses must normally be taken from the following list of selected graduate courses. Courses not on this list are subject to the approval of the Graduate Director.\n\nCO 602 / CS 795 Fundamentals of Optimization\n\n\nCO 673 / CS 794 Optimization for Data Science\n\n\nCO 650 Combinatorial Optimization\n\n\nCO 663 Convex Optimization and Analysis\n\n\nCO 769 Topics in Continuous Optimization(*)\n\n\nCS 638 Principles of Data Management and Use\n\n\nCS 648 Database Systems Implementation\n\n\nCS 654 Distributed Systems\n\n\nCS 680 Introduction to Machine Learning\n\n\nCS 685 Machine Learning: Statistical and Computational Foundations\n\n\nCS 686 Introduction to Artificial Intelligence\n\n\nCS 740 Database Engineering\n\n\nCS 742 Parallel and Distributed Database Systems\n\n\nCS 743 Principles of Database Management and Use\n\n\nCS 786 Probabilistic Inference and Machine Learning\n\n\nCS 798 Advanced Research Topics(*)\n\n\nCS 848 Advanced Topics in Databases(*)\n\n\nCS 856 Advanced Topics in Distributed Computing(*)\n\n\nCS 885 Advanced Topics in Computational Statistics(*)\n\n\nCS 886 Advanced Topics in Artificial Intelligence\n\n\nSTAT 840 Computational Inference\n\n\nSTAT 841 Statistical Learning - Classification\n\n\nSTAT 842 Data Visualization\n\n\nSTAT 844 Statistical Learning - Function Estimation\n\n\nSTAT 946 Topics in Probability and Statistics(*)\n\n\nDS 701/702 Data Science Project 1 & 2\n\n',
#  '\nCO 602 / CS 795 Fundamentals of Optimization\n',
#  '\nCO 673 / CS 794 Optimization for Data Science\n',
#  '\nCO 650 Combinatorial Optimization\n',
#  '\nCO 663 Convex Optimization and Analysis\n',
#  '\nCO 769 Topics in Continuous Optimization(*)\n',
#  '\nCS 638 Principles of Data Management and Use\n',
#  '\nCS 648 Database Systems Implementation\n',
#  '\nCS 654 Distributed Systems\n',
#  '\nCS 680 Introduction to Machine Learning\n',
#  '\nCS 685 Machine Learning: Statistical and Computational Foundations\n',
#  '\nCS 686 Introduction to Artificial Intelligence\n',
#  '\nCS 740 Database Engineering\n',
#  '\nCS 742 Parallel and Distributed Database Systems\n',
#  '\nCS 743 Principles of Database Management and Use\n',
#  '\nCS 786 Probabilistic Inference and Machine Learning\n',
#  '\nCS 798 Advanced Research Topics(*)\n',
#  '\nCS 848 Advanced Topics in Databases(*)\n',
#  '\nCS 856 Advanced Topics in Distributed Computing(*)\n',
#  '\nCS 885 Advanced Topics in Computational Statistics(*)\n',
#  '\nCS 886 Advanced Topics in Artificial Intelligence\n',
#  '\nSTAT 840 Computational Inference\n',
#  '\nSTAT 841 Statistical Learning - Classification\n',
#  '\nSTAT 842 Data Visualization\n',
#  '\nSTAT 844 Statistical Learning - Function Estimation\n',
#  '\nSTAT 946 Topics in Probability and Statistics(*)\n',
#  '\nDS 701/702 Data Science Project 1 & 2\n',
#  '\nNote (*): CO 769, CS 798, CS courses at the 800 level, and STAT courses at the 900 level should be on a topic in Data Science or Artificial Intelligence; they are subject to the approval of the Graduate Officer.\n',
#  '\nIn order to remain in good academic standing, students must maintain an average of 75% and a minimum grade of 70% in all their courses. Progress reports are not required; however, the Director will review students’ overall average every term. Students whose average falls below the program’s minimum requirements may be required to withdraw from the program. The minimum average required by the program is higher than the university’s minimum requirement (70%).\n']

# %%
Waterloo= pd.DataFrame(t, columns=["Course List"])
Waterloo
# Out:
#                                           Course List
# 0   \nStudents must complete at least 9 courses: n...
# 1   \nFoundation courses\n\nStudents are expected ...
# 2   \nStudents are expected to take at most 1 of t...
# 3   \nCS 600 Fundamentals of Computer Science for ...
# 4   \nSTAT 845 Statistical Concepts for Data Scien...
# 5   \nCore courses\n\nStudents are required to tak...
# 6   \nStudents are required to take the following ...
# 7              \nSTAT 847 Exploratory Data Analysis\n
# 8   \n1 of:\n\nCS 651 Data-Intensive Distributed C...
# 9   \nCS 651 Data-Intensive Distributed Computing ...
# 10  \nCS 631 Data-Intensive Distributed Analytics ...
# 11  \n1 of:\n\nSTAT 841 Statistical Learning - Cla...
# 12  \nSTAT 841 Statistical Learning - Classificati...
# 13                    \nSTAT 842 Data Visualization\n
# 14  \nSTAT 844 Statistical Learning - Function Est...
# 15  \n1 of:\n\nCS 638 Principles of Data Managemen...
# 16   \nCS 638 Principles of Data Management and Use\n
# 17         \nCS 648 Database Systems Implementation\n
# 18        \nCS 680 Introduction to Machine Learning\n
# 19  \nCS 685 Machine Learning: Statistical and Com...
# 20  \n1 of:\n\nCO 602 / CS 795 Fundamentals of Opt...
# 21   \nCO 602 / CS 795 Fundamentals of Optimization\n
# 22  \nCO 673 / CS 794 Optimization for Data Science\n
# 23        \nCO 663 Convex Optimization and Analysis\n
# 24  \nElective Courses\n\nStudents must take enoug...
# 25  \nStudents must take enough additional electiv...
# 26   \nCO 602 / CS 795 Fundamentals of Optimization\n
# 27  \nCO 673 / CS 794 Optimization for Data Science\n
# 28              \nCO 650 Combinatorial Optimization\n
# 29        \nCO 663 Convex Optimization and Analysis\n
# 30    \nCO 769 Topics in Continuous Optimization(*)\n
# 31   \nCS 638 Principles of Data Management and Use\n
# 32         \nCS 648 Database Systems Implementation\n
# 33                     \nCS 654 Distributed Systems\n
# 34        \nCS 680 Introduction to Machine Learning\n
# 35  \nCS 685 Machine Learning: Statistical and Com...
# 36  \nCS 686 Introduction to Artificial Intelligen...
# 37                    \nCS 740 Database Engineering\n
# 38  \nCS 742 Parallel and Distributed Database Sys...
# 39  \nCS 743 Principles of Database Management and...
# 40  \nCS 786 Probabilistic Inference and Machine L...
# 41             \nCS 798 Advanced Research Topics(*)\n
# 42         \nCS 848 Advanced Topics in Databases(*)\n
# 43  \nCS 856 Advanced Topics in Distributed Comput...
# 44  \nCS 885 Advanced Topics in Computational Stat...
# 45  \nCS 886 Advanced Topics in Artificial Intelli...
# 46               \nSTAT 840 Computational Inference\n
# 47  \nSTAT 841 Statistical Learning - Classificati...
# 48                    \nSTAT 842 Data Visualization\n
# 49  \nSTAT 844 Statistical Learning - Function Est...
# 50  \nSTAT 946 Topics in Probability and Statistic...
# 51          \nDS 701/702 Data Science Project 1 & 2\n
# 52  \nNote (*): CO 769, CS 798, CS courses at the ...
# 53  \nIn order to remain in good academic standing...

# %%
#Manually dropping the unnecessary text rows
Waterloo=Waterloo.drop([0,1,2,5,6,24,25,51,52,53])
Waterloo
# Out:
#                                           Course List
# 3   \nCS 600 Fundamentals of Computer Science for ...
# 4   \nSTAT 845 Statistical Concepts for Data Scien...
# 7              \nSTAT 847 Exploratory Data Analysis\n
# 8   \n1 of:\n\nCS 651 Data-Intensive Distributed C...
# 9   \nCS 651 Data-Intensive Distributed Computing ...
# 10  \nCS 631 Data-Intensive Distributed Analytics ...
# 11  \n1 of:\n\nSTAT 841 Statistical Learning - Cla...
# 12  \nSTAT 841 Statistical Learning - Classificati...
# 13                    \nSTAT 842 Data Visualization\n
# 14  \nSTAT 844 Statistical Learning - Function Est...
# 15  \n1 of:\n\nCS 638 Principles of Data Managemen...
# 16   \nCS 638 Principles of Data Management and Use\n
# 17         \nCS 648 Database Systems Implementation\n
# 18        \nCS 680 Introduction to Machine Learning\n
# 19  \nCS 685 Machine Learning: Statistical and Com...
# 20  \n1 of:\n\nCO 602 / CS 795 Fundamentals of Opt...
# 21   \nCO 602 / CS 795 Fundamentals of Optimization\n
# 22  \nCO 673 / CS 794 Optimization for Data Science\n
# 23        \nCO 663 Convex Optimization and Analysis\n
# 26   \nCO 602 / CS 795 Fundamentals of Optimization\n
# 27  \nCO 673 / CS 794 Optimization for Data Science\n
# 28              \nCO 650 Combinatorial Optimization\n
# 29        \nCO 663 Convex Optimization and Analysis\n
# 30    \nCO 769 Topics in Continuous Optimization(*)\n
# 31   \nCS 638 Principles of Data Management and Use\n
# 32         \nCS 648 Database Systems Implementation\n
# 33                     \nCS 654 Distributed Systems\n
# 34        \nCS 680 Introduction to Machine Learning\n
# 35  \nCS 685 Machine Learning: Statistical and Com...
# 36  \nCS 686 Introduction to Artificial Intelligen...
# 37                    \nCS 740 Database Engineering\n
# 38  \nCS 742 Parallel and Distributed Database Sys...
# 39  \nCS 743 Principles of Database Management and...
# 40  \nCS 786 Probabilistic Inference and Machine L...
# 41             \nCS 798 Advanced Research Topics(*)\n
# 42         \nCS 848 Advanced Topics in Databases(*)\n
# 43  \nCS 856 Advanced Topics in Distributed Comput...
# 44  \nCS 885 Advanced Topics in Computational Stat...
# 45  \nCS 886 Advanced Topics in Artificial Intelli...
# 46               \nSTAT 840 Computational Inference\n
# 47  \nSTAT 841 Statistical Learning - Classificati...
# 48                    \nSTAT 842 Data Visualization\n
# 49  \nSTAT 844 Statistical Learning - Function Est...
# 50  \nSTAT 946 Topics in Probability and Statistic...

# %%
def remove_stop_words_and_tokenize(tweet):

    
    s1 = ' '
    tokenizer = RegexpTokenizer(r'\w+')         
    tokenised_tweet = tokenizer.tokenize(tweet)
    stopword = nltk.corpus.stopwords.words('english')
    stopword.extend(['Data Science',"Data","Science","Project","\n","CO","STAT","CA","CS","-"])
    #stopword.extend(given_stop_words)
    stopword = list(set(stopword))    
        
    words_rmStop = [word for word in tokenised_tweet if word not in stopword] # remove stop words
#     tweet_no_stop_words = s1.join(words_rmStop)
    
    return words_rmStop

# %%
def remove_punctuation(tweet):

        
    
    tweet = re.sub('[0-9]+', '', tweet) #replacing all numbers by a ''
    tweet = re.sub(r'@[A-Za-z0-9]+','',tweet)
    tweet = re.sub(r'_[A-Za-z0-9]+','',tweet)
    tweet = re.sub(r'&[A-Za-z0-9]+','',tweet)
    tweet = re.sub(r'http[A-Za-z0-9]+','',tweet)
    tweet= re.sub(r'-','',tweet)
    return tweet

# %%
Waterloo['without_punctuation']= Waterloo['Course List'].apply(lambda x: remove_punctuation(x))
Waterloo
# Out:
#                                           Course List                                without_punctuation
# 3   \nCS 600 Fundamentals of Computer Science for ...  \nCS  Fundamentals of Computer Science for Dat...
# 4   \nSTAT 845 Statistical Concepts for Data Scien...  \nSTAT  Statistical Concepts for Data Science ...
# 7              \nSTAT 847 Exploratory Data Analysis\n                \nSTAT  Exploratory Data Analysis\n
# 8   \n1 of:\n\nCS 651 Data-Intensive Distributed C...  \n of:\n\nCS  DataIntensive Distributed Comput...
# 9   \nCS 651 Data-Intensive Distributed Computing ...  \nCS  DataIntensive Distributed Computing (des...
# 10  \nCS 631 Data-Intensive Distributed Analytics ...  \nCS  DataIntensive Distributed Analytics (des...
# 11  \n1 of:\n\nSTAT 841 Statistical Learning - Cla...  \n of:\n\nSTAT  Statistical Learning  Classifi...
# 12  \nSTAT 841 Statistical Learning - Classificati...     \nSTAT  Statistical Learning  Classification\n
# 13                    \nSTAT 842 Data Visualization\n                       \nSTAT  Data Visualization\n
# 14  \nSTAT 844 Statistical Learning - Function Est...  \nSTAT  Statistical Learning  Function Estimat...
# 15  \n1 of:\n\nCS 638 Principles of Data Managemen...  \n of:\n\nCS  Principles of Data Management an...
# 16   \nCS 638 Principles of Data Management and Use\n      \nCS  Principles of Data Management and Use\n
# 17         \nCS 648 Database Systems Implementation\n            \nCS  Database Systems Implementation\n
# 18        \nCS 680 Introduction to Machine Learning\n           \nCS  Introduction to Machine Learning\n
# 19  \nCS 685 Machine Learning: Statistical and Com...  \nCS  Machine Learning: Statistical and Comput...
# 20  \n1 of:\n\nCO 602 / CS 795 Fundamentals of Opt...  \n of:\n\nCO  / CS  Fundamentals of Optimizati...
# 21   \nCO 602 / CS 795 Fundamentals of Optimization\n         \nCO  / CS  Fundamentals of Optimization\n
# 22  \nCO 673 / CS 794 Optimization for Data Science\n        \nCO  / CS  Optimization for Data Science\n
# 23        \nCO 663 Convex Optimization and Analysis\n           \nCO  Convex Optimization and Analysis\n
# 26   \nCO 602 / CS 795 Fundamentals of Optimization\n         \nCO  / CS  Fundamentals of Optimization\n
# 27  \nCO 673 / CS 794 Optimization for Data Science\n        \nCO  / CS  Optimization for Data Science\n
# 28              \nCO 650 Combinatorial Optimization\n                 \nCO  Combinatorial Optimization\n
# 29        \nCO 663 Convex Optimization and Analysis\n           \nCO  Convex Optimization and Analysis\n
# 30    \nCO 769 Topics in Continuous Optimization(*)\n       \nCO  Topics in Continuous Optimization(*)\n
# 31   \nCS 638 Principles of Data Management and Use\n      \nCS  Principles of Data Management and Use\n
# 32         \nCS 648 Database Systems Implementation\n            \nCS  Database Systems Implementation\n
# 33                     \nCS 654 Distributed Systems\n                        \nCS  Distributed Systems\n
# 34        \nCS 680 Introduction to Machine Learning\n           \nCS  Introduction to Machine Learning\n
# 35  \nCS 685 Machine Learning: Statistical and Com...  \nCS  Machine Learning: Statistical and Comput...
# 36  \nCS 686 Introduction to Artificial Intelligen...    \nCS  Introduction to Artificial Intelligence\n
# 37                    \nCS 740 Database Engineering\n                       \nCS  Database Engineering\n
# 38  \nCS 742 Parallel and Distributed Database Sys...  \nCS  Parallel and Distributed Database Systems\n
# 39  \nCS 743 Principles of Database Management and...  \nCS  Principles of Database Management and Use\n
# 40  \nCS 786 Probabilistic Inference and Machine L...  \nCS  Probabilistic Inference and Machine Lear...
# 41             \nCS 798 Advanced Research Topics(*)\n                \nCS  Advanced Research Topics(*)\n
# 42         \nCS 848 Advanced Topics in Databases(*)\n            \nCS  Advanced Topics in Databases(*)\n
# 43  \nCS 856 Advanced Topics in Distributed Comput...  \nCS  Advanced Topics in Distributed Computing...
# 44  \nCS 885 Advanced Topics in Computational Stat...  \nCS  Advanced Topics in Computational Statist...
# 45  \nCS 886 Advanced Topics in Artificial Intelli...  \nCS  Advanced Topics in Artificial Intelligen...
# 46               \nSTAT 840 Computational Inference\n                  \nSTAT  Computational Inference\n
# 47  \nSTAT 841 Statistical Learning - Classificati...     \nSTAT  Statistical Learning  Classification\n
# 48                    \nSTAT 842 Data Visualization\n                       \nSTAT  Data Visualization\n
# 49  \nSTAT 844 Statistical Learning - Function Est...  \nSTAT  Statistical Learning  Function Estimat...
# 50  \nSTAT 946 Topics in Probability and Statistic...  \nSTAT  Topics in Probability and Statistics(*)\n

# %%
tokenizer = RegexpTokenizer(r'\w+') 
Waterloo['tokenized_tweet']= Waterloo['without_punctuation'].apply(lambda x: remove_stop_words_and_tokenize(x) )
#T['tokenized_tweet']
Waterloo
# Out:
#                                           Course List  ...                                    tokenized_tweet
# 3   \nCS 600 Fundamentals of Computer Science for ...  ...  [Fundamentals, Computer, designed, nonCS, majo...
# 4   \nSTAT 845 Statistical Concepts for Data Scien...  ...  [Statistical, Concepts, designed, nonSTAT, maj...
# 7              \nSTAT 847 Exploratory Data Analysis\n  ...                            [Exploratory, Analysis]
# 8   \n1 of:\n\nCS 651 Data-Intensive Distributed C...  ...  [DataIntensive, Distributed, Computing, design...
# 9   \nCS 651 Data-Intensive Distributed Computing ...  ...  [DataIntensive, Distributed, Computing, design...
# 10  \nCS 631 Data-Intensive Distributed Analytics ...  ...  [DataIntensive, Distributed, Analytics, design...
# 11  \n1 of:\n\nSTAT 841 Statistical Learning - Cla...  ...  [Statistical, Learning, Classification, Visual...
# 12  \nSTAT 841 Statistical Learning - Classificati...  ...            [Statistical, Learning, Classification]
# 13                    \nSTAT 842 Data Visualization\n  ...                                    [Visualization]
# 14  \nSTAT 844 Statistical Learning - Function Est...  ...      [Statistical, Learning, Function, Estimation]
# 15  \n1 of:\n\nCS 638 Principles of Data Managemen...  ...  [Principles, Management, Use, Database, System...
# 16   \nCS 638 Principles of Data Management and Use\n  ...                      [Principles, Management, Use]
# 17         \nCS 648 Database Systems Implementation\n  ...                [Database, Systems, Implementation]
# 18        \nCS 680 Introduction to Machine Learning\n  ...                  [Introduction, Machine, Learning]
# 19  \nCS 685 Machine Learning: Statistical and Com...  ...  [Machine, Learning, Statistical, Computational...
# 20  \n1 of:\n\nCO 602 / CS 795 Fundamentals of Opt...  ...  [Fundamentals, Optimization, Optimization, Con...
# 21   \nCO 602 / CS 795 Fundamentals of Optimization\n  ...                       [Fundamentals, Optimization]
# 22  \nCO 673 / CS 794 Optimization for Data Science\n  ...                                     [Optimization]
# 23        \nCO 663 Convex Optimization and Analysis\n  ...                   [Convex, Optimization, Analysis]
# 26   \nCO 602 / CS 795 Fundamentals of Optimization\n  ...                       [Fundamentals, Optimization]
# 27  \nCO 673 / CS 794 Optimization for Data Science\n  ...                                     [Optimization]
# 28              \nCO 650 Combinatorial Optimization\n  ...                      [Combinatorial, Optimization]
# 29        \nCO 663 Convex Optimization and Analysis\n  ...                   [Convex, Optimization, Analysis]
# 30    \nCO 769 Topics in Continuous Optimization(*)\n  ...                 [Topics, Continuous, Optimization]
# 31   \nCS 638 Principles of Data Management and Use\n  ...                      [Principles, Management, Use]
# 32         \nCS 648 Database Systems Implementation\n  ...                [Database, Systems, Implementation]
# 33                     \nCS 654 Distributed Systems\n  ...                             [Distributed, Systems]
# 34        \nCS 680 Introduction to Machine Learning\n  ...                  [Introduction, Machine, Learning]
# 35  \nCS 685 Machine Learning: Statistical and Com...  ...  [Machine, Learning, Statistical, Computational...
# 36  \nCS 686 Introduction to Artificial Intelligen...  ...           [Introduction, Artificial, Intelligence]
# 37                    \nCS 740 Database Engineering\n  ...                            [Database, Engineering]
# 38  \nCS 742 Parallel and Distributed Database Sys...  ...         [Parallel, Distributed, Database, Systems]
# 39  \nCS 743 Principles of Database Management and...  ...            [Principles, Database, Management, Use]
# 40  \nCS 786 Probabilistic Inference and Machine L...  ...      [Probabilistic, Inference, Machine, Learning]
# 41             \nCS 798 Advanced Research Topics(*)\n  ...                       [Advanced, Research, Topics]
# 42         \nCS 848 Advanced Topics in Databases(*)\n  ...                      [Advanced, Topics, Databases]
# 43  \nCS 856 Advanced Topics in Distributed Comput...  ...         [Advanced, Topics, Distributed, Computing]
# 44  \nCS 885 Advanced Topics in Computational Stat...  ...      [Advanced, Topics, Computational, Statistics]
# 45  \nCS 886 Advanced Topics in Artificial Intelli...  ...       [Advanced, Topics, Artificial, Intelligence]
# 46               \nSTAT 840 Computational Inference\n  ...                         [Computational, Inference]
# 47  \nSTAT 841 Statistical Learning - Classificati...  ...            [Statistical, Learning, Classification]
# 48                    \nSTAT 842 Data Visualization\n  ...                                    [Visualization]
# 49  \nSTAT 844 Statistical Learning - Function Est...  ...      [Statistical, Learning, Function, Estimation]
# 50  \nSTAT 946 Topics in Probability and Statistic...  ...                  [Topics, Probability, Statistics]
#
# [44 rows x 3 columns]

# %%
#Detokenize the lists
def detokenize(tokenised_tweet):
   
    s1 = ' '
    tweet_detokenised = s1.join(tokenised_tweet)
    
    return tweet_detokenised

# %%
Waterloo['detokenize']=Waterloo['tokenized_tweet'].apply(lambda x: detokenize(x))
Waterloo
# Out:
#                                           Course List  ...                                         detokenize
# 3   \nCS 600 Fundamentals of Computer Science for ...  ...  Fundamentals Computer designed nonCS major bac...
# 4   \nSTAT 845 Statistical Concepts for Data Scien...  ...  Statistical Concepts designed nonSTAT major ba...
# 7              \nSTAT 847 Exploratory Data Analysis\n  ...                               Exploratory Analysis
# 8   \n1 of:\n\nCS 651 Data-Intensive Distributed C...  ...  DataIntensive Distributed Computing designed m...
# 9   \nCS 651 Data-Intensive Distributed Computing ...  ...  DataIntensive Distributed Computing designed m...
# 10  \nCS 631 Data-Intensive Distributed Analytics ...  ...  DataIntensive Distributed Analytics designed n...
# 11  \n1 of:\n\nSTAT 841 Statistical Learning - Cla...  ...  Statistical Learning Classification Visualizat...
# 12  \nSTAT 841 Statistical Learning - Classificati...  ...                Statistical Learning Classification
# 13                    \nSTAT 842 Data Visualization\n  ...                                      Visualization
# 14  \nSTAT 844 Statistical Learning - Function Est...  ...           Statistical Learning Function Estimation
# 15  \n1 of:\n\nCS 638 Principles of Data Managemen...  ...  Principles Management Use Database Systems Imp...
# 16   \nCS 638 Principles of Data Management and Use\n  ...                          Principles Management Use
# 17         \nCS 648 Database Systems Implementation\n  ...                    Database Systems Implementation
# 18        \nCS 680 Introduction to Machine Learning\n  ...                      Introduction Machine Learning
# 19  \nCS 685 Machine Learning: Statistical and Com...  ...  Machine Learning Statistical Computational Fou...
# 20  \n1 of:\n\nCO 602 / CS 795 Fundamentals of Opt...  ...  Fundamentals Optimization Optimization Convex ...
# 21   \nCO 602 / CS 795 Fundamentals of Optimization\n  ...                          Fundamentals Optimization
# 22  \nCO 673 / CS 794 Optimization for Data Science\n  ...                                       Optimization
# 23        \nCO 663 Convex Optimization and Analysis\n  ...                       Convex Optimization Analysis
# 26   \nCO 602 / CS 795 Fundamentals of Optimization\n  ...                          Fundamentals Optimization
# 27  \nCO 673 / CS 794 Optimization for Data Science\n  ...                                       Optimization
# 28              \nCO 650 Combinatorial Optimization\n  ...                         Combinatorial Optimization
# 29        \nCO 663 Convex Optimization and Analysis\n  ...                       Convex Optimization Analysis
# 30    \nCO 769 Topics in Continuous Optimization(*)\n  ...                     Topics Continuous Optimization
# 31   \nCS 638 Principles of Data Management and Use\n  ...                          Principles Management Use
# 32         \nCS 648 Database Systems Implementation\n  ...                    Database Systems Implementation
# 33                     \nCS 654 Distributed Systems\n  ...                                Distributed Systems
# 34        \nCS 680 Introduction to Machine Learning\n  ...                      Introduction Machine Learning
# 35  \nCS 685 Machine Learning: Statistical and Com...  ...  Machine Learning Statistical Computational Fou...
# 36  \nCS 686 Introduction to Artificial Intelligen...  ...               Introduction Artificial Intelligence
# 37                    \nCS 740 Database Engineering\n  ...                               Database Engineering
# 38  \nCS 742 Parallel and Distributed Database Sys...  ...              Parallel Distributed Database Systems
# 39  \nCS 743 Principles of Database Management and...  ...                 Principles Database Management Use
# 40  \nCS 786 Probabilistic Inference and Machine L...  ...           Probabilistic Inference Machine Learning
# 41             \nCS 798 Advanced Research Topics(*)\n  ...                           Advanced Research Topics
# 42         \nCS 848 Advanced Topics in Databases(*)\n  ...                          Advanced Topics Databases
# 43  \nCS 856 Advanced Topics in Distributed Comput...  ...              Advanced Topics Distributed Computing
# 44  \nCS 885 Advanced Topics in Computational Stat...  ...           Advanced Topics Computational Statistics
# 45  \nCS 886 Advanced Topics in Artificial Intelli...  ...            Advanced Topics Artificial Intelligence
# 46               \nSTAT 840 Computational Inference\n  ...                            Computational Inference
# 47  \nSTAT 841 Statistical Learning - Classificati...  ...                Statistical Learning Classification
# 48                    \nSTAT 842 Data Visualization\n  ...                                      Visualization
# 49  \nSTAT 844 Statistical Learning - Function Est...  ...           Statistical Learning Function Estimation
# 50  \nSTAT 946 Topics in Probability and Statistic...  ...                      Topics Probability Statistics
#
# [44 rows x 4 columns]

# %%
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(str(Waterloo['detokenize']))
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
Waterloo['detokenize'].unique()
#T.detokenize.apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0)
#T['tokenized_tweet'].value_counts()
pd.Series(' '.join(Waterloo.detokenize).split()).value_counts()[:10] #getting a list of top 10 High frequency words
# Out:
# Learning        13
# Optimization    11
# Statistical     10
# Distributed      7
# Machine          7
# Topics           7
# background       6
# major            6
# Database         6
# designed         6
# dtype: int64

# %% [markdown]
# # Carnegie Mellon University Course Lists

# %%
url = 'https://mcds.cs.cmu.edu/learn-us-curriculum'
resp1 = requests.get(url)
soup = BeautifulSoup(resp1.content)
p=[]

for text in soup.find_all(name="div", attrs={"class":"field field-name-body field-type-text-with-summary field-label-hidden"}):
  for li in text.find_all(name="li"):  
    p.append(li.text)
  
p
# Out:
# ['15-619 Cloud Computing',
#  '10-601 Machine Learning',
#  '05-839 Interactive Data Science',
#  '11-631 Data Science Seminar',
#  '15-605 Operating Systems Implementation',
#  '15-618 Parallel Computer Architecture & Programming',
#  '15-640 Distributed Systems',
#  '15-641 Computer Networks',
#  '15-645 Database Systems',
#  '15-712 Advanced and Distributed Operating Systems',
#  '15-719 Advanced Cloud Computing',
#  '15-721 Advanced Databases',
#  '15-746 Advanced Storage Systems',
#  '15-821 Mobile and Pervasive Computing',
#  '36-702 Statistical Machine Learning',
#  '36-705 Intermediate Statistics',
#  '36-725 Convex Optimization',
#  '10-608 Conversational Machine Learning',
#  '10-701 Introduction to Machine Learning (PhD)',
#  '10-703 Deep Reinforcement Learning & Control',
#  '10-708 Probabilistic Graphical Models',
#  '10-715 Advanced Intro to Machine Learning',
#  '10-725 Convex Optimization',
#  '10-805 Machine Learning with Big Data Sets',
#  '11-641 Machine Learning for Text Mining',
#  '11-661 Language and Statistics',
#  '11-727 Computational Semantics for NLP',
#  '11-741 Machine Learning for Text Mining',
#  '11-747 Neural Networks for NLP',
#  '11-755 Machine Learning for Signal Processing',
#  '11-761 Language and Statistics',
#  '11-763 Structured Prediction',
#  '11-777 Advanced Multimedia Machine Learning',
#  '11-785 Intro to Deep Learning',
#  '11-642 Search Engines',
#  '11-747 Neural Networks for NLP',
#  '11-775 Large-Scale Multimedia Analysis',
#  '11-777 Advanced Multimedia Machine Learning',
#  '11-791 Design & Engineering of Intelligent Information Systems',
#  '11-792 Intelligent Systems Project',
#  '11-797 Question Answering',
#  '10-605 Machine Learning with Big Data Sets',
#  '10-805 Machine Learning with Big Data Sets',
#  '11-775 Large-Scale Multimedia Analysis',
#  '05-816 Applied Research Methods',
#  '94-834 Applied Econometrics I & II',
#  '05-821 Social Web',
#  '05-823 E-Learning Design Principles and Methods',
#  '05-833 Applied Gadgets, Sensors & Activity Recognition',
#  '05-836 Usable Privacy and Security',
#  '05-840 Tools for On-Line Learning',
#  '05-872 Rapid Prototyping of Computer Systems',
#  '05-891 Designing Human Centered Systems',
#  '05-899 Crowd Programming',
#  '05-899 Learning Analytics & Educational Data Science',
#  '05-899 Special Topics in HCI: Sensemaking',
#  '05-899 Design of Large-Scale Peer Learning Systems',
#  '05-899 Learning With Peers at Massive Scale',
#  '05-899 Mobile Health']

# %%
carn_mellon= pd.DataFrame(p, columns=['Course list'])
carn_mellon
# Out:
#                                           Course list
# 0                              15-619 Cloud Computing
# 1                             10-601 Machine Learning
# 2                     05-839 Interactive Data Science
# 3                         11-631 Data Science Seminar
# 4             15-605 Operating Systems Implementation
# 5   15-618 Parallel Computer Architecture & Progra...
# 6                          15-640 Distributed Systems
# 7                            15-641 Computer Networks
# 8                             15-645 Database Systems
# 9   15-712 Advanced and Distributed Operating Systems
# 10                    15-719 Advanced Cloud Computing
# 11                          15-721 Advanced Databases
# 12                    15-746 Advanced Storage Systems
# 13              15-821 Mobile and Pervasive Computing
# 14                36-702 Statistical Machine Learning
# 15                     36-705 Intermediate Statistics
# 16                         36-725 Convex Optimization
# 17             10-608 Conversational Machine Learning
# 18      10-701 Introduction to Machine Learning (PhD)
# 19       10-703 Deep Reinforcement Learning & Control
# 20              10-708 Probabilistic Graphical Models
# 21          10-715 Advanced Intro to Machine Learning
# 22                         10-725 Convex Optimization
# 23         10-805 Machine Learning with Big Data Sets
# 24            11-641 Machine Learning for Text Mining
# 25                     11-661 Language and Statistics
# 26             11-727 Computational Semantics for NLP
# 27            11-741 Machine Learning for Text Mining
# 28                     11-747 Neural Networks for NLP
# 29      11-755 Machine Learning for Signal Processing
# 30                     11-761 Language and Statistics
# 31                       11-763 Structured Prediction
# 32        11-777 Advanced Multimedia Machine Learning
# 33                      11-785 Intro to Deep Learning
# 34                              11-642 Search Engines
# 35                     11-747 Neural Networks for NLP
# 36             11-775 Large-Scale Multimedia Analysis
# 37        11-777 Advanced Multimedia Machine Learning
# 38  11-791 Design & Engineering of Intelligent Inf...
# 39                 11-792 Intelligent Systems Project
# 40                          11-797 Question Answering
# 41         10-605 Machine Learning with Big Data Sets
# 42         10-805 Machine Learning with Big Data Sets
# 43             11-775 Large-Scale Multimedia Analysis
# 44                    05-816 Applied Research Methods
# 45                 94-834 Applied Econometrics I & II
# 46                                  05-821 Social Web
# 47    05-823 E-Learning Design Principles and Methods
# 48  05-833 Applied Gadgets, Sensors & Activity Rec...
# 49                 05-836 Usable Privacy and Security
# 50                  05-840 Tools for On-Line Learning
# 51       05-872 Rapid Prototyping of Computer Systems
# 52            05-891 Designing Human Centered Systems
# 53                           05-899 Crowd Programming
# 54  05-899 Learning Analytics & Educational Data S...
# 55          05-899 Special Topics in HCI: Sensemaking
# 56  05-899 Design of Large-Scale Peer Learning Sys...
# 57        05-899 Learning With Peers at Massive Scale
# 58                               05-899 Mobile Health

# %%
carn_mellon['without_punctuations']= carn_mellon['Course list'].apply(lambda x: remove_punctuation(x))
carn_mellon['tokenized_words']=carn_mellon['without_punctuations'].apply(lambda x: remove_stop_words_and_tokenize(x))
carn_mellon['detokenize']=carn_mellon['tokenized_words'].apply(lambda x: detokenize(x))
carn_mellon
# Out:
#                                           Course list  ...                                         detokenize
# 0                              15-619 Cloud Computing  ...                                    Cloud Computing
# 1                             10-601 Machine Learning  ...                                   Machine Learning
# 2                     05-839 Interactive Data Science  ...                                        Interactive
# 3                         11-631 Data Science Seminar  ...                                            Seminar
# 4             15-605 Operating Systems Implementation  ...                   Operating Systems Implementation
# 5   15-618 Parallel Computer Architecture & Progra...  ...         Parallel Computer Architecture Programming
# 6                          15-640 Distributed Systems  ...                                Distributed Systems
# 7                            15-641 Computer Networks  ...                                  Computer Networks
# 8                             15-645 Database Systems  ...                                   Database Systems
# 9   15-712 Advanced and Distributed Operating Systems  ...             Advanced Distributed Operating Systems
# 10                    15-719 Advanced Cloud Computing  ...                           Advanced Cloud Computing
# 11                          15-721 Advanced Databases  ...                                 Advanced Databases
# 12                    15-746 Advanced Storage Systems  ...                           Advanced Storage Systems
# 13              15-821 Mobile and Pervasive Computing  ...                         Mobile Pervasive Computing
# 14                36-702 Statistical Machine Learning  ...                       Statistical Machine Learning
# 15                     36-705 Intermediate Statistics  ...                            Intermediate Statistics
# 16                         36-725 Convex Optimization  ...                                Convex Optimization
# 17             10-608 Conversational Machine Learning  ...                    Conversational Machine Learning
# 18      10-701 Introduction to Machine Learning (PhD)  ...                  Introduction Machine Learning PhD
# 19       10-703 Deep Reinforcement Learning & Control  ...                Deep Reinforcement Learning Control
# 20              10-708 Probabilistic Graphical Models  ...                     Probabilistic Graphical Models
# 21          10-715 Advanced Intro to Machine Learning  ...                    Advanced Intro Machine Learning
# 22                         10-725 Convex Optimization  ...                                Convex Optimization
# 23         10-805 Machine Learning with Big Data Sets  ...                          Machine Learning Big Sets
# 24            11-641 Machine Learning for Text Mining  ...                       Machine Learning Text Mining
# 25                     11-661 Language and Statistics  ...                                Language Statistics
# 26             11-727 Computational Semantics for NLP  ...                        Computational Semantics NLP
# 27            11-741 Machine Learning for Text Mining  ...                       Machine Learning Text Mining
# 28                     11-747 Neural Networks for NLP  ...                                Neural Networks NLP
# 29      11-755 Machine Learning for Signal Processing  ...                 Machine Learning Signal Processing
# 30                     11-761 Language and Statistics  ...                                Language Statistics
# 31                       11-763 Structured Prediction  ...                              Structured Prediction
# 32        11-777 Advanced Multimedia Machine Learning  ...               Advanced Multimedia Machine Learning
# 33                      11-785 Intro to Deep Learning  ...                                Intro Deep Learning
# 34                              11-642 Search Engines  ...                                     Search Engines
# 35                     11-747 Neural Networks for NLP  ...                                Neural Networks NLP
# 36             11-775 Large-Scale Multimedia Analysis  ...                     LargeScale Multimedia Analysis
# 37        11-777 Advanced Multimedia Machine Learning  ...               Advanced Multimedia Machine Learning
# 38  11-791 Design & Engineering of Intelligent Inf...  ...  Design Engineering Intelligent Information Sys...
# 39                 11-792 Intelligent Systems Project  ...                                Intelligent Systems
# 40                          11-797 Question Answering  ...                                 Question Answering
# 41         10-605 Machine Learning with Big Data Sets  ...                          Machine Learning Big Sets
# 42         10-805 Machine Learning with Big Data Sets  ...                          Machine Learning Big Sets
# 43             11-775 Large-Scale Multimedia Analysis  ...                     LargeScale Multimedia Analysis
# 44                    05-816 Applied Research Methods  ...                           Applied Research Methods
# 45                 94-834 Applied Econometrics I & II  ...                          Applied Econometrics I II
# 46                                  05-821 Social Web  ...                                         Social Web
# 47    05-823 E-Learning Design Principles and Methods  ...                ELearning Design Principles Methods
# 48  05-833 Applied Gadgets, Sensors & Activity Rec...  ...       Applied Gadgets Sensors Activity Recognition
# 49                 05-836 Usable Privacy and Security  ...                            Usable Privacy Security
# 50                  05-840 Tools for On-Line Learning  ...                              Tools OnLine Learning
# 51       05-872 Rapid Prototyping of Computer Systems  ...                 Rapid Prototyping Computer Systems
# 52            05-891 Designing Human Centered Systems  ...                   Designing Human Centered Systems
# 53                           05-899 Crowd Programming  ...                                  Crowd Programming
# 54  05-899 Learning Analytics & Educational Data S...  ...                     Learning Analytics Educational
# 55          05-899 Special Topics in HCI: Sensemaking  ...                     Special Topics HCI Sensemaking
# 56  05-899 Design of Large-Scale Peer Learning Sys...  ...            Design LargeScale Peer Learning Systems
# 57        05-899 Learning With Peers at Massive Scale  ...                  Learning With Peers Massive Scale
# 58                               05-899 Mobile Health  ...                                      Mobile Health
#
# [59 rows x 4 columns]

# %%
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(str(carn_mellon['detokenize']))
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
carn_mellon['detokenize'].unique()
#T.detokenize.apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0)
#T['tokenized_tweet'].value_counts()
pd.Series(' '.join(carn_mellon.detokenize).split()).value_counts()[:10] #getting a list of top 10 High frequency words
# Out:
# Learning      19
# Machine       13
# Systems       10
# Advanced       7
# Multimedia     4
# Statistics     3
# Applied        3
# LargeScale     3
# Computer       3
# Computing      3
# dtype: int64

# %% [markdown]
# # University Of Melbourne Course Lists

# %%
url = 'https://study.unimelb.edu.au/find/courses/graduate/master-of-data-science/what-will-i-study/'
resp3 = requests.get(url)
soup = BeautifulSoup(resp3.content)

# %%
program_title=[] 


for div in soup.find_all(name="div", attrs={"class":"subject-programs__group-panel"}):
    for span in div.find_all(name="span", attrs={"class":"subject-programs__title"}):
        program_title.append(span.text)
program_title
# Out:
# ['Methods of Mathematical Statistics',
#  'A First Course In Statistical Learning',
#  'Programming and Software Development',
#  'Algorithms and Complexity',
#  'Elements of Data Processing',
#  'Database Systems & Information Modelling',
#  'Statistical Modelling for Data Science',
#  'Multivariate Statistics for Data Science',
#  'Computational Statistics & Data Science',
#  'Cluster and Cloud Computing',
#  'Statistical Machine Learning',
#  'Advanced Database Systems',
#  'Data Science Project Pt1',
#  'Data Science Project Pt2',
#  'Foundations of Spatial Information',
#  'Spatial Databases',
#  'Spatial Analysis',
#  'Information Visualisation',
#  'Analysis of High-Dimensional Data',
#  'Advanced Statistical Modelling',
#  'Mathematics of Risk',
#  'Optimisation for Industry',
#  'Practice of Statistics & Data Science',
#  'Stochastic Calculus with Applications',
#  'Advanced Probability',
#  'Random Processes',
#  'AI Planning for Autonomy',
#  'Advanced Theoretical Computer Science',
#  'Algorithms for Bioinformatics',
#  'Computational Genomics',
#  'Constraint Programming',
#  'Cryptography and Security',
#  'Declarative Programming',
#  'Distributed Algorithms',
#  'Distributed Systems',
#  'Internet Technologies',
#  'Mobile Computing Systems Programming',
#  'Parallel and Multicore Computing',
#  'Programming Language Implementation',
#  'Natural Language Processing',
#  'Stream Computing and Applications',
#  'Knowledge Management Systems',
#  'Data Warehousing',
#  'Science Communication',
#  'Communication for Research Scientists',
#  'Science in Schools',
#  'Science and Technology Internship',
#  'Data Science Research Project Pt1',
#  'Data Science Research Project Pt2']

# %%
Melbourne= pd.DataFrame(program_title, columns=['Course List'])
Melbourne
# Out:
#                                  Course List
# 0         Methods of Mathematical Statistics
# 1     A First Course In Statistical Learning
# 2       Programming and Software Development
# 3                  Algorithms and Complexity
# 4                Elements of Data Processing
# 5   Database Systems & Information Modelling
# 6     Statistical Modelling for Data Science
# 7   Multivariate Statistics for Data Science
# 8    Computational Statistics & Data Science
# 9                Cluster and Cloud Computing
# 10              Statistical Machine Learning
# 11                 Advanced Database Systems
# 12                  Data Science Project Pt1
# 13                  Data Science Project Pt2
# 14        Foundations of Spatial Information
# 15                         Spatial Databases
# 16                          Spatial Analysis
# 17                 Information Visualisation
# 18         Analysis of High-Dimensional Data
# 19            Advanced Statistical Modelling
# 20                       Mathematics of Risk
# 21                 Optimisation for Industry
# 22     Practice of Statistics & Data Science
# 23     Stochastic Calculus with Applications
# 24                      Advanced Probability
# 25                          Random Processes
# 26                  AI Planning for Autonomy
# 27     Advanced Theoretical Computer Science
# 28             Algorithms for Bioinformatics
# 29                    Computational Genomics
# 30                    Constraint Programming
# 31                 Cryptography and Security
# 32                   Declarative Programming
# 33                    Distributed Algorithms
# 34                       Distributed Systems
# 35                     Internet Technologies
# 36      Mobile Computing Systems Programming
# 37          Parallel and Multicore Computing
# 38       Programming Language Implementation
# 39               Natural Language Processing
# 40         Stream Computing and Applications
# 41              Knowledge Management Systems
# 42                          Data Warehousing
# 43                     Science Communication
# 44     Communication for Research Scientists
# 45                        Science in Schools
# 46         Science and Technology Internship
# 47         Data Science Research Project Pt1
# 48         Data Science Research Project Pt2

# %%
tokenizer = RegexpTokenizer(r'\w+') 
Melbourne['tokenized_tweet']= Melbourne['Course List'].apply(lambda x: remove_stop_words_and_tokenize(x) )
#T['tokenized_tweet']
Melbourne
# Out:
#                                  Course List                                tokenized_tweet
# 0         Methods of Mathematical Statistics            [Methods, Mathematical, Statistics]
# 1     A First Course In Statistical Learning  [A, First, Course, In, Statistical, Learning]
# 2       Programming and Software Development           [Programming, Software, Development]
# 3                  Algorithms and Complexity                       [Algorithms, Complexity]
# 4                Elements of Data Processing                         [Elements, Processing]
# 5   Database Systems & Information Modelling    [Database, Systems, Information, Modelling]
# 6     Statistical Modelling for Data Science                       [Statistical, Modelling]
# 7   Multivariate Statistics for Data Science                     [Multivariate, Statistics]
# 8    Computational Statistics & Data Science                    [Computational, Statistics]
# 9                Cluster and Cloud Computing                    [Cluster, Cloud, Computing]
# 10              Statistical Machine Learning               [Statistical, Machine, Learning]
# 11                 Advanced Database Systems                  [Advanced, Database, Systems]
# 12                  Data Science Project Pt1                                          [Pt1]
# 13                  Data Science Project Pt2                                          [Pt2]
# 14        Foundations of Spatial Information            [Foundations, Spatial, Information]
# 15                         Spatial Databases                           [Spatial, Databases]
# 16                          Spatial Analysis                            [Spatial, Analysis]
# 17                 Information Visualisation                   [Information, Visualisation]
# 18         Analysis of High-Dimensional Data                  [Analysis, High, Dimensional]
# 19            Advanced Statistical Modelling             [Advanced, Statistical, Modelling]
# 20                       Mathematics of Risk                            [Mathematics, Risk]
# 21                 Optimisation for Industry                       [Optimisation, Industry]
# 22     Practice of Statistics & Data Science                         [Practice, Statistics]
# 23     Stochastic Calculus with Applications           [Stochastic, Calculus, Applications]
# 24                      Advanced Probability                        [Advanced, Probability]
# 25                          Random Processes                            [Random, Processes]
# 26                  AI Planning for Autonomy                       [AI, Planning, Autonomy]
# 27     Advanced Theoretical Computer Science              [Advanced, Theoretical, Computer]
# 28             Algorithms for Bioinformatics                   [Algorithms, Bioinformatics]
# 29                    Computational Genomics                      [Computational, Genomics]
# 30                    Constraint Programming                      [Constraint, Programming]
# 31                 Cryptography and Security                       [Cryptography, Security]
# 32                   Declarative Programming                     [Declarative, Programming]
# 33                    Distributed Algorithms                      [Distributed, Algorithms]
# 34                       Distributed Systems                         [Distributed, Systems]
# 35                     Internet Technologies                       [Internet, Technologies]
# 36      Mobile Computing Systems Programming      [Mobile, Computing, Systems, Programming]
# 37          Parallel and Multicore Computing               [Parallel, Multicore, Computing]
# 38       Programming Language Implementation        [Programming, Language, Implementation]
# 39               Natural Language Processing                [Natural, Language, Processing]
# 40         Stream Computing and Applications              [Stream, Computing, Applications]
# 41              Knowledge Management Systems               [Knowledge, Management, Systems]
# 42                          Data Warehousing                                  [Warehousing]
# 43                     Science Communication                                [Communication]
# 44     Communication for Research Scientists          [Communication, Research, Scientists]
# 45                        Science in Schools                                      [Schools]
# 46         Science and Technology Internship                       [Technology, Internship]
# 47         Data Science Research Project Pt1                                [Research, Pt1]
# 48         Data Science Research Project Pt2                                [Research, Pt2]

# %%
Melbourne['detokenize']=Melbourne['tokenized_tweet'].apply(lambda x: detokenize(x))

# %%
Melbourne
# Out:
#                                  Course List  ...                              detokenize
# 0         Methods of Mathematical Statistics  ...         Methods Mathematical Statistics
# 1     A First Course In Statistical Learning  ...  A First Course In Statistical Learning
# 2       Programming and Software Development  ...        Programming Software Development
# 3                  Algorithms and Complexity  ...                   Algorithms Complexity
# 4                Elements of Data Processing  ...                     Elements Processing
# 5   Database Systems & Information Modelling  ...  Database Systems Information Modelling
# 6     Statistical Modelling for Data Science  ...                   Statistical Modelling
# 7   Multivariate Statistics for Data Science  ...                 Multivariate Statistics
# 8    Computational Statistics & Data Science  ...                Computational Statistics
# 9                Cluster and Cloud Computing  ...                 Cluster Cloud Computing
# 10              Statistical Machine Learning  ...            Statistical Machine Learning
# 11                 Advanced Database Systems  ...               Advanced Database Systems
# 12                  Data Science Project Pt1  ...                                     Pt1
# 13                  Data Science Project Pt2  ...                                     Pt2
# 14        Foundations of Spatial Information  ...         Foundations Spatial Information
# 15                         Spatial Databases  ...                       Spatial Databases
# 16                          Spatial Analysis  ...                        Spatial Analysis
# 17                 Information Visualisation  ...               Information Visualisation
# 18         Analysis of High-Dimensional Data  ...               Analysis High Dimensional
# 19            Advanced Statistical Modelling  ...          Advanced Statistical Modelling
# 20                       Mathematics of Risk  ...                        Mathematics Risk
# 21                 Optimisation for Industry  ...                   Optimisation Industry
# 22     Practice of Statistics & Data Science  ...                     Practice Statistics
# 23     Stochastic Calculus with Applications  ...        Stochastic Calculus Applications
# 24                      Advanced Probability  ...                    Advanced Probability
# 25                          Random Processes  ...                        Random Processes
# 26                  AI Planning for Autonomy  ...                    AI Planning Autonomy
# 27     Advanced Theoretical Computer Science  ...           Advanced Theoretical Computer
# 28             Algorithms for Bioinformatics  ...               Algorithms Bioinformatics
# 29                    Computational Genomics  ...                  Computational Genomics
# 30                    Constraint Programming  ...                  Constraint Programming
# 31                 Cryptography and Security  ...                   Cryptography Security
# 32                   Declarative Programming  ...                 Declarative Programming
# 33                    Distributed Algorithms  ...                  Distributed Algorithms
# 34                       Distributed Systems  ...                     Distributed Systems
# 35                     Internet Technologies  ...                   Internet Technologies
# 36      Mobile Computing Systems Programming  ...    Mobile Computing Systems Programming
# 37          Parallel and Multicore Computing  ...            Parallel Multicore Computing
# 38       Programming Language Implementation  ...     Programming Language Implementation
# 39               Natural Language Processing  ...             Natural Language Processing
# 40         Stream Computing and Applications  ...           Stream Computing Applications
# 41              Knowledge Management Systems  ...            Knowledge Management Systems
# 42                          Data Warehousing  ...                             Warehousing
# 43                     Science Communication  ...                           Communication
# 44     Communication for Research Scientists  ...       Communication Research Scientists
# 45                        Science in Schools  ...                                 Schools
# 46         Science and Technology Internship  ...                   Technology Internship
# 47         Data Science Research Project Pt1  ...                            Research Pt1
# 48         Data Science Research Project Pt2  ...                            Research Pt2
#
# [49 rows x 3 columns]

# %%
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(str(Melbourne['detokenize']))
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
Melbourne['detokenize'].unique()
#T.detokenize.apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0)
#T['tokenized_tweet'].value_counts()
pd.Series(' '.join(Melbourne.detokenize).split()).value_counts()[:10]
# Out:
# Systems        5
# Programming    5
# Advanced       4
# Statistics     4
# Statistical    4
# Computing      4
# Modelling      3
# Spatial        3
# Research       3
# Information    3
# dtype: int64

# %% [markdown]
# #University of pennsylvania Course Lists

# %%
url = 'https://catalog.upenn.edu/graduate/programs/data-science-mse/'
resp2 = requests.get(url)
soup = BeautifulSoup(resp2.content)
program=[]


#couln't find the appropriate attribute to extract the course list. please trying inspecting the above list.

  
program
# Out:
# []

# %%
e

# %%
url='https://statistics.stanford.edu/academic-programs/graduate-programs/ms-data-science-2020-21/data-science-track-2019-20'
resp3= requests.get(url)
soup= BeautifulSoup(resp3.content)
program=[]
course_des= []

for text in soup.find_all(name="div", attrs={"class":"field-item even"}):
  for td in text.find_all(name="td"): 


    program.append(td.text)

#for text in soup.find_all(name= 'div', attrs={"class":"searchresult.result-courseresult"}):

  
    #course_des.append(text)

program
# Out:
# ['STATS\xa0200',
#  'Introduction to Statistical Inference',
#  '3',
#  'Aut, Win',
#  'STATS\xa0203',
#  'Introduction to Regression Models and Analysis of Variance',
#  '3',
#  'Win',
#  'or STATS\xa0305A',
#  'Applied Statistics I',
#  '3',
#  'Aut',
#  'STATS\xa0315A',
#  'Modern Applied Statistics: Learning',
#  '3',
#  'Win',
#  'CME\xa0302',
#  'Numerical Linear Algebra',
#  '3',
#  'Aut',
#  'CME\xa0308',
#  'Stochastic Methods in Engineering',
#  '3',
#  'Spr',
#  'Scientific Computing: (3 units)',
#  '\xa0',
#  '\xa0',
#  'CME\xa0212',
#  'Advanced Software Development for Scientists and Engineers (prerequisite: CME\xa0211 )',
#  '3',
#  'Win',
#  'Large-Scale Computing: (3 units)',
#  '\xa0',
#  '\xa0',
#  'CME\xa0213',
#  'Introduction to parallel computing using MPI, openMP, and CUDA',
#  '3',
#  'Win',
#  'CME\xa0323',
#  'Distributed Algorithms and Optimization',
#  '3',
#  'Spr',
#  'CS\xa0246',
#  'Mining Massive Data Sets',
#  '3-4',
#  'Win',
#  'STATS\xa0204',
#  'Sampling',
#  '3',
#  'Spr',
#  'STATS\xa0266',
#  'Advanced Statistical Methods for Observational Studies',
#  '2-3',
#  'Spr',
#  'ECON\xa0271',
#  'Intermediate Econometrics II',
#  '2-5',
#  'Win',
#  'MS&E 327',
#  'Topics in Causal Inference',
#  '3',
#  'Aut',
#  'CME\xa0364A',
#  'Convex Optimization I',
#  '3',
#  'Win',
#  'STATS\xa0231',
#  'Statistical Learning Theory',
#  '3',
#  '\xa0',
#  'STATS\xa0245',
#  'Data, Models and Applications to Healthcare Analytics',
#  '3',
#  'Sum',
#  'STATS\xa0315B',
#  'Modern Applied Statistics: Data Mining',
#  '3',
#  'Spr',
#  'CS\xa0221',
#  'Artificial Intelligence: Principles and Techniques',
#  '3-4',
#  'Aut, Spr',
#  'CS\xa0224N',
#  'Natural Language Processing with Deep Learning',
#  '3-4',
#  'Win',
#  'CS\xa0230',
#  'Deep Learning',
#  '3-4',
#  'Aut, Win, Spr',
#  'CS\xa0231N',
#  'Convolutional Neural Networks for Visual Recognition',
#  '3-4',
#  'Spr',
#  'CS\xa0234',
#  'Reinforcement Learning',
#  '3',
#  'Win',
#  'CS\xa0236',
#  'Deep Generative Models',
#  '3-4',
#  'Aut']

# %%
course_des=[]
course_des=soup.find(name="div", attrs={"class":"searchresult.search-courseresult"})


#p = soup.find(name="p", attrs={"class":"course__description"})
#text = "".join(p.text)



course_des
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-4339a886df9b> in <module>()
#       1 course_des=[]
#       2 course_des=soup.find(name="div", attrs={"class":"searchresult.search-courseresult"})
# ----> 3 course_des.append(div.text)
#       4
#       5 #p = soup.find(name="p", attrs={"class":"course__description"})
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
stanford=[]
courses=[]
p=[]
li=[]
des=[]
for div in soup.find_all(name="div", attrs={"class":"searchresult.search-courseresult"}):
     for p in div.find_all(name="p"):
         p.append(p.text)
     for li in div.find_all(name='li'):
         p.append(li.text)
     p.append(li)
     des.append(p)
stanford.append(courses)        
df_melbourne = pd.DataFrame(stanford)
